# %%
import numpy as np
import re
import csv
import random

random.seed(42)

def tokenize(text):
    text = text.lower()
    words = re.findall(r"\b[a-zA-Z]+\b", text)
    return words
def load_data(file_name, max_labels=100):
    data = []
    labels_counter = {}
    with open(file_name, 'r', encoding="utf-8") as file:
        first = True
        for row in csv.reader(file):
            if not first:
                label = int(row[0])-1
                if label in [0,1,2]:
                    data.append((set(tokenize(row[1]+' '+row[2])), label))
            else:
                first = not first
    random.shuffle(data)
    short_data = []
    for row in data:
        label = row[1]
        if label not in labels_counter.keys():
            labels_counter[label] = 0
        if labels_counter[label] < max_labels:
            labels_counter[label]+=1
            short_data.append(row)
    return short_data

row_data_train = load_data(r".\train.csv")
row_data_test = load_data(r".\test.csv", 80)

print(row_data_train)
print(row_data_test)
# Out:
# [({'scene', 'his', 'dominated', 'dari', 'duo', 'and', 'persian', 'is', 'a', 'music', 'ex', 'wife', 'started', 'afghanistan', 'pakistan', 'he', 'musical', 'popular', 'singer', 'in', 'during', 'were', 'born', 'pashto', 'prominent', 'mangal', 'who', 'early', 'afghan', 'naghma', 'the', 'laghman', 'sings'}, 1), ({'an', 'ermocrate', 'flowers', 'italian', 'of', 'still', 'painter', 'with', 'was', 'lifes', 'bucchi', 'mainly'}, 1), ({'records', 'here', 'later', 'addition', 'columbia', 'co', 'anywhere', 'debut', 'chris', 'and', 'year', 'by', 'american', 'an', 'nothing', 'is', 'a', 'one', 'but', 'wrote', 'long', 'signed', 'music', 'hot', 'cagle', 'allan', 'gary', 's', 'number', 'randy', 'was', 'songs', 'released', 'anything', 'singer', 'which', 'in', 'charted', 'radio', 'born', 'single', 'charts', 'william', 'billboard', 'brice', 'goes', 'that', 'august', 'houser', 'to', 'also', 'on', 'the', 'country'}, 1), ({'things', 'privately', 'english', 'his', 'merchant', 'of', 'ladslove', 'navy', 'and', 'according', 'pseudonym', 'poet', 'an', 'a', 'wrote', 'uranian', 'timothy', 'leslie', 'was', 'include', 'works', 'philebus', 'he', 'which', 'in', 'were', 'fantasies', 'arch', 'smith', 'd', 'who', 'barford', 'under', 'young', 'printed', 'whimsies', 'to', 'doctor', 'john', 'the', 'lyrics'}, 1), ({'high', 'terms', 'singapore', 'of', 'became', 'and', 'schools', 'officially', 'programme', 'year', 'secondary', 'starting', 'embarked', 'is', 'a', 'among', 'academic', 'rvhs', 'integrated', 'been', 'results', 'milestone', 'which', 'school', 'in', 'from', 'river', 'consistently', 'top', 'ranked', 'full', 'new', 'valley', 'has', 'the', 'on'}, 0), ({'swimming', 'for', 'of', 'events', 'distance', 'pohang', 'games', 'london', 'finalist', 'asian', 'january', 'standard', 'at', 'guangzhou', 'specialized', 'by', 'ulsan', 'is', 'a', 'swimmer', 'korean', 'long', 'freestyle', 'fina', 's', 'the', 'women', 'tournament', 'time', 'kim', 'summer', 'aged', 'ga', 'in', 'from', 'olympics', 'born', 'eclipsing', 'eul', 'm', 'as', 'who', 'dong', 'korea', 'youngest', 'she', 'qualified', 'b', 'south', 'entry'}, 2), ({'for', 'of', 'son', 'mordechai', 'and', 'yeedle', 'renowned', 'werdyger', 'super', 'name', 'american', 'an', 'is', 'a', 'heb', 'yiddish', 'yehudah', 'stage', 'nickname', 'hebrew', 'he', 'star', 'singer', 'jewish', 'orthodox', 'born', 'david', 'grandson', 'hasidic', 'the', 'ben', 'cantor'}, 1), ({'appeared', 'he', 'a', 'july', 'between', 'in', 'may', 'films', 'claesson', 'swedish', 'was', 'and', 'film', 'actor'}, 1), ({'cross', 'nonfiction', 'genres', 'for', 'are', 'of', 'interest', 'screen', 'performance', 'and', 'at', 'enrolls', 'portland', 'areas', 'is', 'a', 'options', 'writing', 'nature', 'the', 'major', 'stage', 'based', 'students', 'mfa', 'popular', 'genre', 'elective', 'in', 'creative', 'maine', 'graduate', 'four', 'pursued', 'including', 'as', 'university', 'translation', 'states', 'poetry', 'other', 'stonecoast', 'literary', 'fiction', 'approximately', 'southern', 'student', 'program', 'united'}, 0), ({'collegiate', 'former', 'st', 'player', 'for', 'three', 'draft', 'allentown', 'first', 'fifth', 'after', 'york', 'league', 'michael', 'at', 'jets', 'round', 'by', 'american', 'an', 'is', 'a', 'selected', 'july', 'professional', 'eastern', 'basketball', 'bonavanture', 'was', 'seasons', 'career', 'playing', 'he', 'years', 'overall', 'played', 'in', 'born', 'six', 'knicks', 'new', 'brendan', 'nba', 'followed', 'the', 'mccann'}, 2), ({'high', 'kentucky', 'of', 'seneca', 'located', 'point', 'mca', 'and', 'at', 'schools', 'louisville', 'is', 'a', 'lane', 'neighborhood', 'hikes', 'part', 'career', 'county', 'goldsmith', 'school', 'in', 'academy', 'magnet', 'it', 'usa', 'ky', 'public', 'the', 'jefferson'}, 0), ({'welsh', 'prince', 'found', 'ap', 'text', 'of', 'poem', 'c', 'son', 'and', 'earliest', 'hendregadredd', 'madog', 'y', 'by', 'poet', 'is', 'a', 'powys', 'llywarch', 'language', 'praise', 'llywelyn', 'was', 'nam', 'llaety', 'fl', 'manuscript', 'which', 'in', 'heir', ...
# [({'an', 'is', 'for', 'iran', 'omid', 'in', 'footballer', 'iranian', 'born', 'foolad', 'league', 'october', 'pro', 'the', 'khaledi', 'playing'}, 2), ({'rate', 'on', 'many', 'of', 'work', 'later', 'conference', 'located', 'graduation', 'and', 'educational', 'owned', 'by', 'secondary', 'ethic', 'is', 'cicero', 'a', 'adventists', 'ia', 'one', 'develop', 'academic', 'education', 'campus', 'average', 'life', 'obtain', 'operated', 'strong', 'students', 'indiana', 'school', 'in', 'class', 'academy', 'five', 'good', 'as', 'useful', 'institutions', 'seventh', 'size', 'twenty', 'also', 'has', 'adventist', 'known', 'the', 'day'}, 0), ({'irvine', 'peter', 'enrolment', 'of', 'teacher', 'includes', 'kilmarnock', 'surrounding', 'built', 'and', 'johnston', 'serving', 'position', 'by', 'secondary', 'acting', 'areas', 'is', 'a', 'left', 'ayrshire', 'was', 'loudoun', 'somewhere', 'previous', 'flood', 'which', 'school', 'in', 'east', 'academy', 'current', 'brian', 'pupils', 'around', 'as', 'head', 'district', 'retired', 'outskirts', 'perth', 'headmaster', 'scotland', 'succeeded', 'galston', 'new', 'rural', 'valley', 'to', 'walker', 'leaving', 'the', 'graeme'}, 0), ({'composer', 'for', 'his', 'many', 'tomoya', 'wave', 'musician', 'games', 'and', 'master', 'primary', 'is', 'a', 'july', 'hedgehog', 'game', 'video', 'tokyo', 'japan', 'in', 'from', 'contributions', 'born', 'ohtani', 'sonic', 'known', 'the'}, 1), ({'english', 'theological', 'of', 'both', 'place', 'evangelical', 'located', 'offers', 'and', 'galilee', 'american', 'an', 'is', 'undergraduate', 'takes', 'degrees', 'israel', 'quarter', 'teaching', 'arabic', 'in', 'graduate', 'seminary', 'nets', 'nazareth', 'the'}, 0), ({'for', 'sesvete', 'came', 'november', 'midfielder', 'bosnian', 'is', 'a', 'plays', 'football', 'currently', 'fc', 'he', 'summer', 'in', 'spartak', 'born', 'nk', 'who', 'croatian', 'josip', 'to', 'trnava'}, 2), ({'for', 'player', 'of', 'league', 'position', 'lbs', 'vlantimiros', 'and', 'forward', 'at', 'tall', 'is', 'a', 'plays', 'professional', 'basketball', 'serbian', 'ft', 'weighs', 'vlado', 'he', 'spelling', 'in', 'giankovits', 'vladimiros', 'born', 'march', 'vlanto', 'm', 'panathinaikos', 'vlantimir', 'kg', 'greek', 'basket', 'small', 'alternate', 'vladimir', 'the'}, 2), ({'wonderland', 'english', 'for', 'walliams', 'his', 'dawes', 'newspaper', 'richard', 'of', 'work', 'well', 'stars', 'with', 'and', 'alice', 'independent', 'by', 'comedy', 'an', 'scorekeeping', 'is', 'comedian', 'matt', 'influential', 'little', 'panel', 's', 'women', 'was', 'uk', 'game', 'list', 'he', 'shooting', 'singer', 'in', 'show', 'placed', 'gay', 'born', 'march', 'tweedledum', 'david', 'baby', 'television', 'as', 'tweedledee', 'actor', 'portrayals', 'britain', 'george', 'most', 'matthew', 'men', 'seventh', 'may', 'british', 'lucas', 'best', 'screenwriter', 'known', 'the'}, 1), ({'for', 'dr', 'november', 'cs', 'dirang', 'botswanan', 'international', 'is', 'a', 'plays', 'footballer', 'bosco', 'in', 'born', 'moloi', 'who', 'club', 'linafoot', 'congolese', 'don', 'the'}, 2), ({'roach', 'for', 'his', 'ambient', 'many', 'italian', 'of', 'be', 'musician', 'with', 'and', 'michael', 'deep', 'listenings', 'magazine', 'pseudonym', 'by', 'static', 'an', 'is', 'featured', 'being', 'famous', 'music', 'stearns', 'minimalistic', 'was', 'interviews', 'he', 'gianluigi', 'dedicated', 'where', 'gasparetti', 'march', 'perhaps', 'artists', 'as', 'including', 'editor', 'steve', 'characterized', 'organic', 'best', 'to', 'can', 'april', 'has', 'atmospheric', 'known', 'the', 'role'}, 1), ({'their', 'for', 'stint', 'his', 'work', 'well', 'lead', 'album', 'with', 'and', 'caine', 'tour', 'american', 'an', 'is', 'rohn', 'july', 'extreme', 'francis', 'gary', 'band', 's', 'subsequent', 'rock', 'iii', 'latest', 'was', 'released', 'he', 'years', 'halen', 'singer', 'in', 'van', 'saudades', 'born', 'solo', 'reunited', 'cherone', 'as', 'group', 'short', 'august', 'de', 'best', 'recent', 'has', 'recordings', 'songwriter', 'known', 'the ...

# %%
all_words = []
for tokens, _ in row_data_train:
    all_words += tokens
all_words = sorted(set(all_words))
len(all_words)
# Out:
# 3576

# %%
def one_hot(data, all_words):
    n = len(data)
    m = len(all_words)
    encoded = np.zeros((n, m), dtype=int)
    labels = np.zeros(n, dtype=int)
    for i in range(n):
        for j in range(m):
            if all_words[j] in data[i][0]:
                encoded[i][j] = 1
        labels[i] = data[i][1]
    return encoded, labels

X_train, y_train = one_hot(row_data_train, all_words)
X_test, y_test = one_hot(row_data_test, all_words)

# %%
class WeightedKNN:
    def __init__(self,  n_neighbors=5, metric='l2', n_classes=None, weights='distance'):
        self.n_neighbors = n_neighbors
        self.metric = (lambda a: np.linalg.norm(a, axis=1, ord=1)) if metric == 'l1' else (lambda a: np.linalg.norm(a,axis=1))
        self.n_classes = n_classes or len(np.unique(y_train))
    def fit(self, X_train, y_train):
        self.X_train = X_train
        self.y_train = y_train
    def _softmin(self, dists):
        logits = - dists
        exps = np.exp(logits - np.max(logits))
        return exps / np.sum(exps)

    def predict_proba(self, x):
        dists = self.metric(self.X_train-x)
        idx = np.argsort(dists)[:self.n_neighbors]
        neigh_y = self.y_train[idx]
        neigh_d = dists[idx]
        weights = self._softmin(neigh_d)
        print(neigh_y)
        print(neigh_d)
        print(weights)
        scores = np.zeros(self.n_classes)
        for w, y in zip(weights, neigh_y):
            scores[y] += w
        probs = np.exp(scores - np.max(scores))
        probs /= np.sum(probs)
        print(probs)
        return probs

    def predict(self, X):
        return np.array([np.argmax(self.predict_proba(x)) for x in X])

# %%
model = WeightedKNN(n_neighbors=25, metric='l1')
model.fit(X_train, y_train)
predicted = model.predict(X_test[0:1])
print(predicted, y_test[0:1])
# Out:
# [1 2 2 2 1 0 2 2 2 2 1 2 1 2 0 0 1 2 2 0 2 2 1 0 0]
# [12. 13. 13. 14. 15. 15. 15. 15. 16. 16. 16. 16. 16. 17. 17. 17. 17. 18.
#  18. 18. 18. 18. 18. 18. 18.]
# [0.45277501 0.16656662 0.16656662 0.06127643 0.02254234 0.02254234
#  0.02254234 0.02254234 0.00829286 0.00829286 0.00829286 0.00829286
#  0.00829286 0.00305077 0.00305077 0.00305077 0.00305077 0.00112232
#  0.00112232 0.00112232 0.00112232 0.00112232 0.00112232 0.00112232
#  0.00112232]
# [0.2413662  0.38389943 0.37473437]
# [1] [2]
