# %%
import pickle
import textwrap
from pprint import pprint


def print_wrapped(text, width=80):
    wrapped_text = textwrap.fill(text, width=width)
    print(wrapped_text)


with open("data.pkl", "rb") as f:
    pavlov = pickle.load(f)

with open("data_my.pkl", "rb") as f:
    bert_base_NER_Russian = pickle.load(f)


def read_texts_from_file(filename):
    with open(filename, "r", encoding="utf-8") as file:
        content = file.read()

    texts = content.split("\n\n")

    cleaned_texts = []
    for text in texts:
        cleaned_text = " ".join(
            line.strip() for line in text.split("\n") if line.strip()
        )
        if cleaned_text:
            cleaned_texts.append(cleaned_text)

    return cleaned_texts


tests = read_texts_from_file("test.txt")
my_labels = (
    (
        ("ООН", "Аббревиатура"),
        ("Нью-Йорке", "Город"),
        ("России", "Страна"),
        ("Сергея Лаврова", "Имя Фамилия"),
        ("Антониу Гутерришем", "Имя Фамилия"),
        ("Израилем", "Страна"),
        ("Лавров", "Фамилия"),
        ("Российская Федерация", "Страна"),
        ("МИД", "Аббревиатура"),
        ("Марии Захаровой", "Имя Фамилия"),
        ("США", "Страна"),
        ("Энтони Блинкен", "Имя Фамилия"),
        ("Германии", "Страна"),
        ("Олаф Шольц", "Имя Фамилия"),
        ("Лавров", "Фамилия"),
        ("Каир", "Город"),
        ("Египта", "Страна"),
        ("Абдул-Фаттахом ас-Сиси", "Имя Фамилия"),
    ),
    (
        ("Александр Сергеевич Пушкин", "Имя Отчество Фамилия"),
        ("Москва", "Город"),
        ("Санкт-Петербург", "Город"),
        ("Сергей Львович Пушкин", "Имя Отчество Фамилия"),
        ("Надежда Осиповна", "Мия Отчество"),
        ("Ганнибал", "Фамилия"),
        ("Петра", "Имя"),
        ("Абрама Петровича Ганнибала", "Имя Отчество Фамилия"),
        ("Пушкин", "Фамилия"),
        ("Гавриил Державин", "Имя Фамилия"),
        ("Василий Жуковский", "Имя Фамилия"),
    ),
    (
        ("Облонских", "Фамилия"),
        ("Степан Аркадьич Облонский", "Имя Отчество Фамилия"),
        ("Дарьи Александровны", "Имя Отчество"),
        ("Долли", "Имя"),
        ("Константине Дмитриевиче Левине", "Имя Отчество Фамилия"),
        ("Матвей", "Имя"),
        ("Анны Аркадьевны Карениной", "Имя Отчество Фамилия"),
        ("Степана Аркадьича", "Имя Отчество"),
    ),
    (
        ("Москве", "Город"),
        ("Государственной Третьяковской галереи", "Организация"),
        ("Крымском Валу", "Улица"),
        ("Михаила Александровича Врубеля", "Имя Отчество Фамилия"),
        ("Ольга Любимова", "Имя Фамилия"),
        ("Зельфира Трегулова", "Имя Фамилия"),
        ("Ирина Шуманова", "Имя Фамилия"),
        ("Третьяковки", "Организация"),
        ("Русского музея", "Организация"),
        ("Санкт-Петербурге", "Город"),
        ("Демон сидящий", "Произведение"),
        ("Царевна-Лебедь", "Произведение"),
    ),
    (
        ("Надежда", "Название корабля"),
        ("Нева", "Название корабля"),
        ("Ивана Фёдоровича Крузенштерна", "Имя Отчество Фамилия"),
        ("Надеждой", "Название корабля"),
        ("Крузенштерн", "Фамилия"),
        ("Невой", "Название корабля"),
        ("Юрий Фёдорович Лисянский", "Имя Отчество Фамилия"),
        ("Кронштадта", "Город"),
        ("Горн", "Название мыса"),
        ("Гавайские острова", "Острова"),
        ("Камчатки", "Полуостров"),
        ("Японию", "Страна"),
        ("Николай Петрович Резанов", "Имя Отчество Фамилия"),
        ("Юнона и Авось", "Произведение"),
        ("Тихого океана", "Океан"),
    ),
    (
        ("Сергей Орел", "Имя Фамилия"),
        ("Орел", "Город"),
        ("Турции", "Страна"),
        ("Иван Рыбкин", "Имя Фамилия"),
        ("Рыбкин", "Организация"),
        ("Берлине", "Город"),
        ("Река Ангара", "Река"),
        ("Ангара", "Организация"),
        ("Ангара Петров", "Имя Фамилия"),
        ("Париж", "Город"),
        ("Токарь", "Фамилия"),
        ("Иванова", "Фамилия"),
        ("Токарь", "Произведения")
    )
)

# %%
for i, text in enumerate(tests):
    print("=" * 38 + str(i) + "=" * 38)
    print_wrapped(text)
    print()
    n = max(len(pavlov[i]), len(bert_base_NER_Russian[i]), len(my_labels[i]))
    for j in range(n):
        from_pavlov = ""
        from_bert_base_NER_Russian = ""
        from_my = ""
        if j < len(my_labels[i]):
            from_my = f"Word: {my_labels[i][j][0]}, Entity: {my_labels[i][j][1]}"
        if j < len(pavlov[i]):
            from_pavlov = f"Word: {pavlov[i][j][0]}, Entity: {pavlov[i][j][1]}"
        if j < len(bert_base_NER_Russian[i]):
            from_bert_base_NER_Russian = f"Word: {bert_base_NER_Russian[i][j][0]}, Entity: {bert_base_NER_Russian[i][j][1]}"
        from_pavlov_space_count = 50 - len(from_pavlov)
        if from_pavlov_space_count < 1:
            from_pavlov_space_count = 1
        from_bert_base_NER_Russian_space_count = 50 - len(from_bert_base_NER_Russian)
        if from_bert_base_NER_Russian_space_count < 1:
            from_bert_base_NER_Russian_space_count = 1
        print(
            from_pavlov,
            " " * from_pavlov_space_count,
            from_bert_base_NER_Russian,
            " " * from_bert_base_NER_Russian_space_count,
            from_my,
        )
# Out:
# ======================================0======================================
# В среду, 15 мая, в штаб-квартире ООН в Нью-Йорке состоялась встреча министра
# иностранных дел России Сергея Лаврова с генеральным секретарем организации
# Антониу Гутерришем. Основной темой переговоров стала эскалация напряженности в
# зоне конфликта между Израилем и Палестиной. Лавров подчеркнул, что Российская
# Федерация призывает все стороны к немедленному прекращению огня. По словам
# официального представителя МИД Марии Захаровой, встреча прошла в конструктивном
# ключе. Ранее с аналогичными заявлениями выступили госсекретарь США Энтони
# Блинкен и канцлер Германии Олаф Шольц. В ближайшее время Лавров также планирует
# посетить Каир для консультаций с президентом Египта Абдул-Фаттахом ас-Сиси.
#
# Word: среду, Entity: B-TIME                         Word: Нью, Entity: CITY                             Word: ООН, Entity: Аббревиатура
# Word: 15, Entity: B-DATE                            Word: -, Entity: CITY                               Word: Нью-Йорке, Entity: Город
# Word: мая, Entity: I-DATE                           Word: Йорке, Entity: CITY                           Word: России, Entity: Страна
# Word: ООН, Entity: B-ORG                            Word: России, Entity: COUNTRY                       Word: Сергея Лаврова, Entity: Имя Фамилия
# Word: Нью, Entity: B-GPE                            Word: Сергея, Entity: FIRST_NAME                    Word: Антониу Гутерришем, Entity: Имя Фамилия
# Word: -, Entity: I-GPE                              Word: Лаврова, Entity: LAST_NAME                    Word: Израилем, Entity: Страна
# Word: Йорке, Entity: I-GPE                          Word: Антониу, Entity: FIRST_NAME                   Word: Лавров, Entity: Фамилия
# Word: России, Entity: B-GPE                         Word: Гутерришем, Entity: LAST_NAME                 Word: Российская Федерация, Entity: Страна
# Word: Сергея, Entity: B-PERSON                      Word: Израилем, Entity: COUNTRY                     Word: МИД, Entity: Аббревиатура
# Word: Лаврова, Entity: I-PERSON                     Word: Палестиной, Entity: COUNTRY                   Word: Марии Захаровой, Entity: Имя Фамилия
# Word: Антониу, Entity: B-PERSON                     Word: Лавров, Entity: LAST_NAME                     Word: США, Entity: Страна
# Word: Гутерришем., Entity: I-PERSON                 Word: Российская, Entity: COUNTRY                   Word: Энтони Блинкен, Entity: Имя Фамилия
# Word: Израилем, Entity: B-GPE                       Word: Федерация, Entity: COUNTRY                    Word: Германии, Entity: Страна
# Word: Палестиной., Entity: B-GPE                    Word: Марии, Entity: FIRST_NAME                     Word: Олаф Шольц, Entity: Имя Фамилия
# Word: Лавров, Entity: B-PERSON                      Word: Захаровой, Entity: LAST_NAME                  Word: Лавров, Entity: Фамилия
# Word: Российская, Entity: B-ORG                     Word: США, Entity: COUNTRY                          Word: Каир, Entity: Город
# Word: Федерация, Entity: I-ORG                      Word: Энтони, Entity: FIRST_NAME                    Word: Египта, Entity: Страна
# Word: МИД, Entity: B-ORG                            Word: Блинкен, Entity: LAST_NAME                    Word: Абдул-Фаттахом ас-Сиси, Entity: Имя Фамилия
# Word: Марии, Entity: B-PERSON                       Word: Германии, Entity: COUNTRY
# Word: Захаровой, Entity: I-PERSON                   Word: Олаф, Entity: FIRST_NAME
# Word: США, Entity: B-GPE                            Word: Шольц, Entity: LAST_NAME
# Word: Энтони, Entity: B-PERSON                      Word: Лавров, Entity: LAST_NAME
# Word: Блинкен, Entity: I-PERSON                     Word: Каир, Entity: COUNTRY
# Word: Германии, Entity: B-GPE                       Word: Египта, Entity: COUNTRY
# Word: Олаф, Entity: B-PERSON                        Word: Абдул - Фаттахом, Entity: FIRST_NAME
# Word: Шольц., Entity: I-PERSON                      Word: а, Entity: LAST_NAME
# Word: Лавров, Entity: B-PERSON                      Word: ##с -, Entity: LAST_NAME
# Word: Каир, Entity: B-GPE                           Word: Сиси, Entity: LAST_NAME
# Word: Египта, Entity: B-GPE
# Word: Абдул, Entity: B-PERSON
# Word: -, Entity: I-PERSON
# Word: Фаттахом, Entity: I-PERSON
# Word: ас, Entity: I-PERSON
# Word: -, Entity: I-PERSON
# Word: Сиси, Entity: I-PERSON
# ======================================1======================================
# Александр Сергеевич Пушкин (26 мая [6 июня] 1799, Москва — 29 января [10
# февраля] 1837, Санкт-Петербург) — русский поэт, драматург и прозаик, заложивший
# основы русского реалистического направления, литературный критик и теоретик
# литературы, историк, публицист; один из самых авторитетных литературных деятелей
# первой трети XIX века. Родился в небогатой дворянской семье. Его отец, Сергей
# Львович Пушкин, был светским острословом и поэтом-любителем. Мать, Надежда
# Осиповна, урожденная Ганнибал, была внучкой арапа Петра Великого — Абрама
# Петровича Ганнибала. В 1811 году Пушкин поступил в только что открывшийся
# Царскосельский лицей, где его талант был высоко оценен такими современниками,
# как Гавриил Державин и Василий Жуковский.
#
# Word: Александр, Entity: B-PERSON                   Word: Александр, Entity: FIRST_NAME                 Word: Александр Сергеевич Пушкин, Entity: Имя Отчество Фамилия
# Word: Сергеевич, Entity: I-PERSON                   Word: Сергеевич, Entity: MIDDLE_NAME                Word: Москва, Entity: Город
# Word: Пушкин, Entity: I-PERSON                      Word: Пушкин, Entity: LAST_NAME                     Word: Санкт-Петербург, Entity: Город
# Word: 26, Entity: B-DATE                            Word: Москва, Entity: CITY                          Word: Сергей Львович Пушкин, Entity: Имя Отчество Фамилия
# Word: мая, Entity: I-DATE                           Word: Санкт, Entity: CITY                           Word: Надежда Осиповна, Entity: Мия Отчество
# Word: [, Entity: I-DATE                             Word: -, Entity: CITY                               Word: Ганнибал, Entity: Фамилия
# Word: 6, Entity: I-DATE                             Word: Петербург, Entity: CITY                       Word: Петра, Entity: Имя
# Word: июня, Entity: I-DATE                          Word: Сергей, Entity: FIRST_NAME                    Word: Абрама Петровича Ганнибала, Entity: Имя Отчество Фамилия
# Word: ], Entity: I-DATE                             Word: Львович, Entity: MIDDLE_NAME                  Word: Пушкин, Entity: Фамилия
# Word: 1799, Entity: I-DATE                          Word: Пушкин, Entity: LAST_NAME                     Word: Гавриил Державин, Entity: Имя Фамилия
# Word: Москва, Entity: B-GPE                         Word: Надежда, Entity: FIRST_NAME                   Word: Василий Жуковский, Entity: Имя Фамилия
# Word: 29, Entity: B-DATE                            Word: Осипов, Entity: MIDDLE_NAME
# Word: января, Entity: I-DATE                        Word: Ганнибал, Entity: LAST_NAME
# Word: [, Entity: I-DATE                             Word: Петра, Entity: FIRST_NAME
# Word: 10, Entity: I-DATE                            Word: Великого, Entity: LAST_NAME
# Word: февраля, Entity: I-DATE                       Word: Абрама, Entity: FIRST_NAME
# Word: ], Entity: I-DATE                             Word: Петровича, Entity: MIDDLE_NAME
# Word: 1837, Entity: I-DATE                          Word: Ганнибала, Entity: LAST_NAME
# Word: Санкт, Entity: B-GPE                          Word: Пушкин, Entity: LAST_NAME
# Word: -, Entity: I-GPE                              Word: Гавриил, Entity: FIRST_NAME
# Word: Петербург, Entity: I-GPE                      Word: Державин, Entity: LAST_NAME
# Word: русский, Entity: B-NORP                       Word: Василий, Entity: FIRST_NAME
# Word: русского, Entity: B-NORP                      Word: Жуковский, Entity: LAST_NAME
# Word: первой, Entity: B-DATE
# Word: трети, Entity: I-DATE
# Word: XIX, Entity: I-DATE
# Word: века., Entity: I-DATE
# Word: Сергей, Entity: B-PERSON
# Word: Львович, Entity: I-PERSON
# Word: Пушкин, Entity: I-PERSON
# Word: Надежда, Entity: B-PERSON
# Word: Осиповна, Entity: I-PERSON
# Word: Ганнибал, Entity: B-PERSON
# Word: Петра, Entity: B-PERSON
# Word: Великого, Entity: I-PERSON
# Word: Абрама, Entity: B-PERSON
# Word: Петровича, Entity: I-PERSON
# Word: Ганнибала., Entity: I-PERSON
# Word: 1811, Entity: B-DATE
# Word: Пушкин, Entity: B-PERSON
# Word: Царскосельский, Entity: B-ORG
# Word: лицей, Entity: I-ORG
# Word: Гавриил, Entity: B-PERSON
# Word: Державин, Entity: I-PERSON
# Word: Василий, Entity: B-PERSON
# Word: Жуковский, Entity: I-PERSON
# ======================================2======================================
# Все смешалось в доме Облонских. Жена узнала, что муж был в связи с бывшею в их
# доме француженкою-гувернанткой, и объявила мужу, что не может жить с ним в одном
# доме. Положение это продолжалось уже третий день и мучительно чувствовалось и
# самими супругами, и всеми членами семьи, и домочадцами. Князь Степан Аркадьич
# Облонский сидел в своем кабинете, с недоумением глядя на письма от жены, Дарьи
# Александровны, которую дома все звали Долли. Он вспомнил о своем друге,
# Константине Дмитриевиче Левине, который недавно приезжал из деревни, и подумал,
# что тот, пожалуй, мог бы помочь ему советом. В это время в дверь постучали, и
# вошел лакей Матвей, доложив о приходе Анны Аркадьевны Карениной, сестры Степана
# Аркадьича.
#
# Word: Облонских., Entity: B-PERSON                  Word: Облонских, Entity: LAST_NAME                  Word: Облонских, Entity: Фамилия
# Word: третий, Entity: B-DATE                        Word: Степан, Entity: FIRST_NAME                    Word: Степан Аркадьич Облонский, Entity: Имя Отчество Фамилия
# Word: день, Entity: I-DATE                          Word: Аркадьич, Entity: MIDDLE_NAME                 Word: Дарьи Александровны, Entity: Имя Отчество
# Word: Степан, Entity: B-PERSON                      Word: Облонский, Entity: LAST_NAME                  Word: Долли, Entity: Имя
# Word: Аркадьич, Entity: I-PERSON                    Word: Дарьи, Entity: FIRST_NAME                     Word: Константине Дмитриевиче Левине, Entity: Имя Отчество Фамилия
# Word: Облонский, Entity: I-PERSON                   Word: Александров, Entity: MIDDLE_NAME              Word: Матвей, Entity: Имя
# Word: Дарьи, Entity: B-PERSON                       Word: Долли, Entity: FIRST_NAME                     Word: Анны Аркадьевны Карениной, Entity: Имя Отчество Фамилия
# Word: Александровны, Entity: I-PERSON               Word: Константине, Entity: FIRST_NAME               Word: Степана Аркадьича, Entity: Имя Отчество
# Word: Долли., Entity: B-PERSON                      Word: Дмитриевич, Entity: MIDDLE_NAME
# Word: Константине, Entity: B-PERSON                 Word: Левине, Entity: LAST_NAME
# Word: Дмитриевиче, Entity: I-PERSON                 Word: Матвей, Entity: FIRST_NAME
# Word: Левине, Entity: I-PERSON                      Word: Анны, Entity: FIRST_NAME
# Word: Матвей, Entity: B-PERSON                      Word: Аркадьевны, Entity: MIDDLE_NAME
# Word: Анны, Entity: B-PERSON                        Word: Каренин, Entity: LAST_NAME
# Word: Аркадьевны, Entity: I-PERSON                  Word: Степана, Entity: FIRST_NAME
# Word: Карениной, Entity: I-PERSON                   Word: Аркадьича, Entity: MIDDLE_NAME
# Word: Степана, Entity: B-PERSON
# Word: Аркадьича, Entity: I-PERSON
# ======================================3======================================
# Вчера в Москве, в здании Государственной Третьяковской галереи на Крымском Валу,
# состоялось торжественное открытие масштабной ретроспективы, посвященной
# творчеству великого русского художника Михаила Александровича Врубеля. На
# церемонии присутствовали министр культуры Ольга Любимова, директор галереи
# Зельфира Трегулова, а также потомки мастера. Куратор выставки, Ирина Шуманова,
# отметила, что в экспозиции представлено более 300 работ из собраний Третьяковки,
# Русского музея в Санкт-Петербурге и частных коллекций. Особый интерес публики
# вызывают такие знаковые полотна, как "Демон сидящий" и "Царевна-Лебедь".
# Выставка продлится до конца августа.
#
# Word: Москве, Entity: B-GPE                         Word: Москве, Entity: CITY                          Word: Москве, Entity: Город
# Word: Государственной, Entity: B-FAC                Word: Михаила, Entity: FIRST_NAME                   Word: Государственной Третьяковской галереи, Entity: Организация
# Word: Третьяковской, Entity: I-FAC                  Word: Александровича, Entity: MIDDLE_NAME           Word: Крымском Валу, Entity: Улица
# Word: галереи, Entity: I-FAC                        Word: Врубеля, Entity: LAST_NAME                    Word: Михаила Александровича Врубеля, Entity: Имя Отчество Фамилия
# Word: Крымском, Entity: B-FAC                       Word: Ольга, Entity: FIRST_NAME                     Word: Ольга Любимова, Entity: Имя Фамилия
# Word: Валу, Entity: I-FAC                           Word: Любимова, Entity: LAST_NAME                   Word: Зельфира Трегулова, Entity: Имя Фамилия
# Word: русского, Entity: B-NORP                      Word: Зельфира, Entity: FIRST_NAME                  Word: Ирина Шуманова, Entity: Имя Фамилия
# Word: Михаила, Entity: B-PERSON                     Word: Трегулова, Entity: LAST_NAME                  Word: Третьяковки, Entity: Организация
# Word: Александровича, Entity: I-PERSON              Word: Ирина, Entity: FIRST_NAME                     Word: Русского музея, Entity: Организация
# Word: Врубеля., Entity: I-PERSON                    Word: Шуманова, Entity: LAST_NAME                   Word: Санкт-Петербурге, Entity: Город
# Word: Ольга, Entity: B-PERSON                       Word: Санкт, Entity: CITY                           Word: Демон сидящий, Entity: Произведение
# Word: Любимова, Entity: I-PERSON                    Word: -, Entity: CITY                               Word: Царевна-Лебедь, Entity: Произведение
# Word: Зельфира, Entity: B-PERSON                    Word: Петербурге, Entity: CITY
# Word: Трегулова, Entity: I-PERSON
# Word: Ирина, Entity: B-PERSON
# Word: Шуманова, Entity: I-PERSON
# Word: более, Entity: B-CARDINAL
# Word: 300, Entity: I-CARDINAL
# Word: Третьяковки, Entity: B-ORG
# Word: Русского, Entity: B-ORG
# Word: музея, Entity: I-ORG
# Word: Санкт, Entity: B-GPE
# Word: -, Entity: I-GPE
# Word: Петербурге, Entity: I-GPE
# Word: ", Entity: B-WORK_OF_ART
# Word: Демон, Entity: I-WORK_OF_ART
# Word: сидящий, Entity: I-WORK_OF_ART
# Word: ", Entity: I-WORK_OF_ART
# Word: ", Entity: B-WORK_OF_ART
# Word: Царевна, Entity: I-WORK_OF_ART
# Word: -, Entity: I-WORK_OF_ART
# Word: Лебедь, Entity: I-WORK_OF_ART
# Word: ", Entity: I-WORK_OF_ART
# Word: конца, Entity: B-DATE
# Word: августа, Entity: I-DATE
# ======================================4======================================
# Первая российская кругосветная экспедиция была осуществлена в 1803—1806 годах на
# кораблях «Надежда» и «Нева» под командованием Ивана Фёдоровича Крузенштерна.
# «Надеждой» командовал непосредственно Крузенштерн, а «Невой» — его ближайший
# помощник Юрий Фёдорович Лисянский. Экспедиция вышла из Кронштадта, обогнула мыс
# Горн, посетила Гавайские острова и достигла Камчатки. Важную роль в этом
# плавании сыграл и участник посольства в Японию — Николай Петрович Резанов,
# известный благодаря рок-опере "Юнона и Авось". Эта экспедиция внесла огромный
# вклад в изучение Тихого океана и составила ряд карт, которыми пользовались
# многие последующие мореплаватели.
#
# Word: Первая, Entity: B-ORDINAL                     Word: Ивана, Entity: FIRST_NAME                     Word: Надежда, Entity: Название корабля
# Word: российская, Entity: B-NORP                    Word: Фёдоровича, Entity: MIDDLE_NAME               Word: Нева, Entity: Название корабля
# Word: 1803, Entity: B-DATE                          Word: Крузенштерна, Entity: LAST_NAME               Word: Ивана Фёдоровича Крузенштерна, Entity: Имя Отчество Фамилия
# Word: —, Entity: I-DATE                             Word: Крузенштерн, Entity: LAST_NAME                Word: Надеждой, Entity: Название корабля
# Word: 1806, Entity: I-DATE                          Word: Юрий, Entity: FIRST_NAME                      Word: Крузенштерн, Entity: Фамилия
# Word: годах, Entity: I-DATE                         Word: Фёдорович, Entity: MIDDLE_NAME                Word: Невой, Entity: Название корабля
# Word: Надежда, Entity: B-PRODUCT                    Word: Лисянский, Entity: LAST_NAME                  Word: Юрий Фёдорович Лисянский, Entity: Имя Отчество Фамилия
# Word: Нева, Entity: B-PRODUCT                       Word: Кронштадт, Entity: CITY                       Word: Кронштадта, Entity: Город
# Word: Ивана, Entity: B-PERSON                       Word: Японию, Entity: COUNTRY                       Word: Горн, Entity: Название мыса
# Word: Фёдоровича, Entity: I-PERSON                  Word: Николай, Entity: FIRST_NAME                   Word: Гавайские острова, Entity: Острова
# Word: Крузенштерна., Entity: I-PERSON               Word: Петрович, Entity: MIDDLE_NAME                 Word: Камчатки, Entity: Полуостров
# Word: Крузенштерн, Entity: B-PERSON                 Word: Резанов, Entity: LAST_NAME                    Word: Японию, Entity: Страна
# Word: Юрий, Entity: B-PERSON                                                                            Word: Николай Петрович Резанов, Entity: Имя Отчество Фамилия
# Word: Фёдорович, Entity: I-PERSON                                                                       Word: Юнона и Авось, Entity: Произведение
# Word: Лисянский., Entity: I-PERSON                                                                      Word: Тихого океана, Entity: Океан
# Word: Кронштадта, Entity: B-GPE
# Word: мыс, Entity: B-LOC
# Word: Горн, Entity: B-LOC
# Word: Гавайские, Entity: B-LOC
# Word: острова, Entity: I-LOC
# Word: Камчатки., Entity: B-LOC
# Word: Японию, Entity: B-GPE
# Word: Николай, Entity: B-PERSON
# Word: Петрович, Entity: I-PERSON
# Word: Резанов, Entity: I-PERSON
# Word: ", Entity: B-WORK_OF_ART
# Word: Юнона, Entity: I-WORK_OF_ART
# Word: и, Entity: I-WORK_OF_ART
# Word: Авось, Entity: I-WORK_OF_ART
# Word: ", Entity: I-WORK_OF_ART
# Word: Тихого, Entity: B-LOC
# Word: океана, Entity: I-LOC
# ======================================5======================================
# Сергей Орел приехал в город Орел из Турции, где купил марку с орлом. Его друг
# Иван Рыбкин, работающий в компании "Рыбкин", сейчас в Берлине. Река Ангара течет
# мимо завода "Ангара", а директор Ангара Петров уехал в Париж. Доктор Токарь
# лечил токаря Иванова, который читал книгу "Токарь".
#
# Word: Сергей, Entity: B-PERSON                      Word: Сергей, Entity: FIRST_NAME                    Word: Сергей Орел, Entity: Имя Фамилия
# Word: Орел, Entity: I-PERSON                        Word: Орел, Entity: LAST_NAME                       Word: Орел, Entity: Город
# Word: Орел, Entity: B-GPE                           Word: Орел, Entity: CITY                            Word: Турции, Entity: Страна
# Word: Турции, Entity: B-GPE                         Word: Турции, Entity: COUNTRY                       Word: Иван Рыбкин, Entity: Имя Фамилия
# Word: Иван, Entity: B-PERSON                        Word: Иван, Entity: FIRST_NAME                      Word: Рыбкин, Entity: Организация
# Word: Рыбкин, Entity: I-PERSON                      Word: Рыбкин, Entity: LAST_NAME                     Word: Берлине, Entity: Город
# Word: ", Entity: B-ORG                              Word: Рыбкин, Entity: LAST_NAME                     Word: Река Ангара, Entity: Река
# Word: Рыбкин, Entity: I-ORG                         Word: Берлине, Entity: CITY                         Word: Ангара, Entity: Организация
# Word: ", Entity: I-ORG                              Word: Ангара, Entity: FIRST_NAME                    Word: Ангара Петров, Entity: Имя Фамилия
# Word: Берлине., Entity: B-GPE                       Word: Петров, Entity: LAST_NAME                     Word: Париж, Entity: Город
# Word: Ангара, Entity: B-LOC                         Word: Париж, Entity: CITY                           Word: Токарь, Entity: Фамилия
# Word: завода, Entity: B-ORG                         Word: Иванова, Entity: LAST_NAME                    Word: Иванова, Entity: Фамилия
# Word: ", Entity: I-ORG                                                                                  Word: Токарь, Entity: Произведения
# Word: Ангара, Entity: I-ORG
# Word: ", Entity: I-ORG
# Word: Ангара, Entity: B-PERSON
# Word: Петров, Entity: I-PERSON
# Word: Париж., Entity: B-GPE
# Word: Токарь, Entity: B-PERSON
# Word: Иванова, Entity: B-PERSON
# Word: Токарь, Entity: B-WORK_OF_ART
# Word: ", Entity: I-WORK_OF_ART

# %% [markdown]
# # Отчёт по лабораторной работе
#
# В рамках лабораторной работы была использована обязательная модель `ner_ontonotes_bert_mult`, а также найденная на Hugging Face модель `bert-base-NER-Russian`. Все шесть документов были дополнительно размечены вручную для верификации результатов.
#
# ## Сравнительный анализ моделей
#
# ### Поддерживаемые сущности
# * **`ner_ontonotes_bert_mult`** распознаёт имена людей (без разделения на составные части), организации, страны, города, даты и географические объекты
# * **`bert-base-NER-Russian`** работает с именами, странами и городами, но при этом различает составные части имён
#
# ## Анализ ошибок
#
# ### Модель `bert-base-NER-Russian`
# * **Географические ошибки**: `Каир` помечен как `COUNTRY` вместо `CITY`
# * **Некорректный разбор имён**: `Петра Великого` разделён на `FIRST_NAME` и `LAST_NAME`, хотя "Великий" является прозвищем
# * **Путаница с организациями**: "Рыбкин" распознан как фамилия, а не как название компании
# * **Пропуск сущностей**: не распознал фамилию "Токарь" у доктора
#
# ### Модель `ner_ontonotes_bert_mult`
# * **Ошибочная классификация**: `Российская Федерация` помечена как организация
# * **Разрыв сущностей**: `мыс Горн` разбит на две отдельные локации
# * **Проблемы с пунктуацией**: забывает открывающую кавычку в `"Токарь"`
# * **Прилипание точек**: часто присоединяет точку к последнему слову предложения
#
# ## Выводы
#
# Найденная модель `bert-base-NER-Russian` демонстрирует лучшие результаты в извлечении имён людей благодаря детальному анализу составных частей. В то же время модель `ner_ontonotes_bert_mult` показывает более стабильную работу в общем случае, успешно справляясь со сложными синтаксическими конструкциями, как в последнем документе.
